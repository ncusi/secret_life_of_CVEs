# %%
import pandas as pd

# %% [markdown]
# ## List of projects

# %% [markdown]
# One of parameters / input data is Pandas DataFrame with projects as one of main columns.
#
# This DataFrame will be enriched by this notebook / script with project metadata features.

# %%
infile='df_commits_with_one_project.parquet'
infile='../data/combined_df_filename'
infile
# Out:
# '../data/combined_df_filename'

# %%
pwd()
# Out:
# '/home/jnareb/echoes_of_vulnerabilities_code/projects_stats'

# %%
df=pd.read_parquet(infile)

# %% [markdown]
# Examine the DataFrame

# %%
df.columns
# Out:
# Index(['commit', 'commit_cves', 'commiter_time', 'author_time',
#        'project_names', 'total_number_of_files', 'dep_requirements',
#        'dep_cargo', 'dep_go_mod', 'dep_ivy',
#        ...
#        'lang_AspectJ', 'lang_HLSL', 'lang_ShaderLab', 'lang_SMT', 'lang_XC',
#        'lang_Charity', 'lang_xBase', 'lang_WebIDL', 'lang_Genie', 'lang_Gosu'],
#       dtype='object', length=9339)

# %%
#projects=df['project_name'].unique()
projects=df['project_names'].unique()
len(projects)

[p for pp.split(';') for pp in projects if (pp is not None)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [102], in <cell line: 5>()
#       2 projects=df['project_names'].unique()
#       3 len(projects)
# ----> 5 [p for p in pp.split(';') for pp in projects if (pp is not None)]
#
# NameError: name 'pp' is not defined

# %% [markdown]
# The starting point could be just a list of projects

# %%
projects_s=pd.Series(projects)

# %%
pd.Series(projects).to_csv('interesting_projects_list.csv', sep=';', header=False, index=False)

# %% [markdown]
# ## Retrieving the list of projects (alt)

# %%
project_s=pd.read_csv('interesting_projects_list.csv', sep=';', header=None)[0]
project_s
# Out:
# 0                                          mirror-rpm_exim
# 1                                      buildroot_buildroot
# 2                                                Exim_exim
# 3                                    pfsense_FreeBSD-ports
# 4        salsa.debian.org_security-tracker-team_securit...
#                                ...
# 35753                            ESIEASecurityClub_exploit
# 35754                                       klange_toaruos
# 35755                                LearnPress_learnpress
# 35756                         apache_cordova-plugin-camera
# 35757                                 stong_CVE-2020-15368
# Name: 0, Length: 35758, dtype: object

# %%
projects=project_s.unique()
projects[:10]
# Out:
# array(['mirror-rpm_exim', 'buildroot_buildroot', 'Exim_exim',
#        'pfsense_FreeBSD-ports',
#        'salsa.debian.org_security-tracker-team_security-tracker',
#        'git-portage_git-portage', 'felenk_ports', 'gentoo_gentoo',
#        'ulm_gentoo-x86-historical', 'bitrig_bitrig-ports'], dtype=object)

# %% [markdown]
# ## Accessing MongoDB database

# %% [markdown]
# Accessing the World of Code MongoDB database with various metadata is described in https://github.com/woc-hack/tutorial#mongo-database
#
# > On the da1 server, there is a MongoDB server holding some relevant data. This data includes some information that was used for data analysis in the past. Mongo provides an excellent place to store relatively small data without requiring relational information.
# >
# > Two collections the WoC database cand be helpful for sampling projects and authors `A_metadata.V` and `P.metadata.V` where `V` represents the version (e.g., `T`) , `A` stands for aliased author id and `P` for deforked repository name.

# %% [markdown]
# There is no direct access to the `da1` server.  One needs to tunnel connection via `da0`, otherwise one would get the following error
#
# ```
# ServerSelectionTimeoutError: da1.eecs.utk.edu:27017: [Errno 113] No route to host, Timeout: 30s, Topology Description: <TopologyDescription id: 639216df3fa72534c7d7e1c5, topology_type: Unknown, servers: [<ServerDescription ('da1.eecs.utk.edu', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('da1.eecs.utk.edu:27017: [Errno 113] No route to host')>]>
# ```

# %% [markdown]
# One possible solution is to use [`ssh-pymongo`](https://pypi.org/project/ssh-pymongo/) (which in turn is a thin wrapper around [`sshtunnel`](https://pypi.org/project/sshtunnel/) and [`pymongo`](https://pypi.org/project/pymongo/)), see e.g.
# https://stackoverflow.com/questions/56239184/python-script-to-connect-to-remote-mongodb-using-ssh-tunnel-and-pymongo-client-i

# %% [markdown]
# The configuration for connecting to World of Code servers via `da0` gateway looks like this:
# ```
# Host da0
# 	Hostname da0.eecs.utk.edu
# 	Port 443
# 	User <username>
# 	IdentityFile <path to private key, e.g. %d/.ssh/id_rsa_woc>
# ```

# %% [markdown]
# > When on the da1 server, you can gain access to the MongoDB server simply by running the command `mongo`, or, when on any other da server, you can gain access by running `mongo --host "da1.eecs.utk.edu"`.
#
# from https://github.com/woc-hack/tutorial

# %% [markdown]
# This means that when being logged onto WoC gateway, namely 'da0' host, one would need to use the latter

# %%
import os

username = os.environ['JUPYTERHUB_USER']
username
# Out:
# 'jnareb'

# %%
home = os.getenv('HOME', '/home/'+username)
home
# Out:
# '/home/jnareb'

# %% [markdown]
# This SSH configuration, reproduced as `ssh_pymongo` configuration, looks like this (together with information about the host where MongoDB database is)

# %% [markdown]
# **NOTE**: since 12.12.2022, after recovered from da2 failure,
#
# > 3. if you use mongodb, change server to da5 from da1
#
# source: Discord (https://discord.gg/fKPFxzWqZX)

# %%
from ssh_pymongo import MongoSession

session = MongoSession(
    host="da0.eecs.utk.edu",
    port=443,
    user=username,                      # this may need adjusting
    key=home+'/.ssh/id_rsa_woc',        # this may need adjusting
    uri="mongodb://da5.eecs.utk.edu/"
)

client=session.connection
client
# Out:
# MongoClient(host=['127.0.0.1:45255'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# Example from [PyMongo documentation](https://pymongo.readthedocs.io/en/stable/tutorial.html#getting-a-single-document-with-find-one):

# %%
import pprint
pprint.pprint(client['WoC']['A_metadata.U'].find_one())
# Out:
# {'AuthorID': 'Sulthan-Basha <34763305+Sulthan-Basha@users.noreply.github.com>',
#  'EarliestCommitDate': 1619434588,
#  'FileInfo': {'other': 4},
#  'Gender': 'male',
#  'LatestCommitDate': 1619434588,
#  'MonNcmt': {'2018-10': 2,
#              '2019-07': 2,
#              '2019-08': 1,
#              '2019-09': 4,
#              '2020-05': 2,
#              '2020-06': 2,
#              '2020-10': 2,
#              '2021-04': 4,
#              '2021-07': 3},
#  'MonNprj': {'2018-10': 1,
#              '2019-07': 1,
#              '2019-08': 1,
#              '2019-09': 2,
#              '2020-05': 1,
#              '2020-06': 1,
#              '2020-10': 1,
#              '2021-04': 1,
#              '2021-07': 1},
#  'NumActiveMon': 9,
#  'NumCommits': 22,
#  'NumFiles': 4,
#  'NumOriginatingBlobs': 10,
#  'NumProjects': 10,
#  '_id': ObjectId('628f66290788e585aa1d4d36')}

# %% [markdown]
# Example from the WoC tutorial, split into two, slightly modified:

# %%
#import pymongo
#
#client = pymongo.MongoClient("mongodb://da1.eecs.utk.edu/")

# %%
db = client['WoC']
coll = db['A_metadata.U']

dataset = coll.find({}, no_cursor_timeout=True).limit(10)
for data in dataset:
    a = data["AuthorID"].encode('utf-8').strip()
    print(a)

dataset.close()
# Out:
# b'Sulthan-Basha <34763305+Sulthan-Basha@users.noreply.github.com>'
# b'a <250550879@qq.com>'
# b'Christopher Hannon <nc@dhcp93.merunorth110.iit.edu>'
# b'Emily Hedgecock <Emily@omsystems.co.uk>'
# b'tb-lab <f297138735+tb@gmail.com>'
# b'itsamemonisha <77173644+itsamemonisha@users.noreply.github.com>'
# b'fredericnasri <nasrifreddy@gmail.com>'
# b'yukasansan <64906781+yukasansan@users.noreply.github.com>'
# b'xParanormalx <info@2moons.eu>'
# b'ibrahem-abualfoul <76413554+ibrahem-abualfoul@users.noreply.github.com>'

# %% [markdown]
# ## Browsing project metadata

# %% [markdown]
# Let's take an example project

# %%
project=projects_s[1]
project
# Out:
# 'buildroot_buildroot'

# %% [markdown]
# Find every metadata about this project in MongoDB

# %%
coll = db['P_metadata.U']
coll
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:45255'], document_class=dict, tz_aware=False, connect=True), 'WoC'), 'P_metadata.U')

# %% [markdown]
# Let's examine the basic structure of the MonngoDB collection, based on an example of a single project

# %%
pprint.pprint(coll.find_one())
# Out:
# {'CommunitySize': 1,
#  'Core': {'johan-84 <83859842+johan-84@users.noreply.github.com>': '2'},
#  'EarliestCommitDate': 1620460902,
#  'FileInfo': {'other': 2},
#  'LatestCommitDate': 1620781111,
#  'MonNauth': {'2021-05': 1},
#  'MonNcmt': {'2021-05': 2},
#  'NumActiveMon': 1,
#  'NumAuthors': 1,
#  'NumBlobs': 2,
#  'NumCommits': 2,
#  'NumCore': 1,
#  'NumFiles': 2,
#  'NumForks': 0,
#  'ProjectID': 'johan-84_johan-84',
#  '_id': ObjectId('628e3343f7956706ea414615')}

# %% [markdown]
# Let's examine selected project

# %%
project
# Out:
# 'buildroot_buildroot'

# %%
pprint.pprint(coll.find_one({'ProjectID': project}))
# Out:
# {'ApiInfo': {'C:': 37203,
#              'C:alloca.h': 655,
#              'C:assert.h': 3231,
#              'C:cdefs.h': 552,
#              'C:ctype.h': 4627,
#              'C:dirent.h': 1736,
#              'C:elf.h': 898,
#              'C:endian.h': 957,
#              'C:errno.h': 14651,
#              'C:fcntl.h': 6722,
#              'C:features.h': 11407,
#              'C:file.h': 550,
#              'C:float.h': 696,
#              'C:getopt.h': 1825,
#              'C:grp.h': 895,
#              'C:if.h': 434,
#              'C:in.h': 1688,
#              'C:inet.h': 1136,
#              'C:inttypes.h': 604,
#              'C:ioctl.h': 2152,
#              'C:langinfo.h': 481,
#              'C:libgen.h': 709,
#              'C:libmtd.h': 445,
#              'C:libubi.h': 418,
#              'C:limits.h': 4569,
#              'C:link.h': 697,
#              'C:locale.h': 1948,
#              'C:malloc.h': 550,
#              'C:mman.h': 2270,
#              'C:mount.h': 657,
#              'C:mtd-user.h': 585,
#              'C:nameser.h': 493,
#              'C:netdb.h': 2043,
#              'C:param.h': 1673,
#              'C:paths.h': 1197,
#              'C:pmap_clnt.h': 550,
#              'C:poll.h': 1356,
#              'C:pthread.h': 2112,
#              'C:pwd.h': 806,
#              'C:resolv.h': 619,
#              'C:resource.h': 1018,
#              'C:rpc.h': 1182,
#              'C:sched.h': 790,
#              'C:setjmp.h': 597,
#              'C:signal.h': 4043,
#              'C:socket.h': 2649,
#              'C:stat.h': 5245,
#              'C:stdarg.h': 3613,
#              'C:stdbool.h': 1347,
#              'C:stddef.h': 4331,
#              'C:stdint.h': 4191,
#              'C:stdio.h': 12993,
#              'C:stdio_ext.h': 652,
#              'C:stdlib.h': 14387,
#              'C:string.h': 15365,
#              'C:syscall.h': 4631,
#              'C:sysdep.h': 668,
#              'C:sysmacros.h': 608,
#              'C:termios.h': 538,
#              'C:time.h': 4372,
#              'C:times.h': 475,
#              'C:tls.h': 814,
#              'C:types.h': 9246,
#              'C:uClibc_mutex.h': 899,
#              'C:uClibc_page.h': 559,
#              'C:uClibc_uintmaxtostr.h': 559,
#              'C:uClibc_uwchar.h': 531,
#              'C:uio.h': 780,
#              'C:un.h': 566,
#              'C:unistd.h': 15277,
#              'C:utime.h': 515,
#              'C:utsname.h': 935,
#              'C:vfs.h': 462,
#              'C:wait.h': 1511,
#              'C:wchar.h': 1315,
#              'C:wctype.h': 585,
#              'C:wordsize.h': 721,
#              'C:xdr.h': 552,
#              'C:xlocale.h': 526,
#              'PY:': 6783,
#              'PY:Command': 950,
#              'PY:ConfigParser': 498,
#              'PY:Emulator.Emulator': 663,
#              'PY:argparse': 468,
#              'PY:batoceraFiles': 1636,
#              'PY:configparser': 613,
#              'PY:controllersConfig': 558,
#              'PY:datetime': 421,
#              'PY:generators.Generator.Generator': 950,
#              'PY:glob': 433,
#              'PY:infra.basetest': 879,
#              'PY:json': 747,
#              'PY:os': 4864,
#              'PY:os.path': 766,
#              'PY:re': 1538,
#              'PY:settings': 447,
#              'PY:settings.unixSettings.UnixSettings': 770,
#              'PY:shutil': 1094,
#              'PY:subprocess': 1581,
#              'PY:sys': 2626,
#              'PY:time': 889,
#              'PY:utils.logger.eslog': 775},
#  'CommunitySize': 4897,
#  'Core': {' <apenwarr@gmail.com>': '1492',
#           'A.I <ailis@paw.zone>': '255',
#           'A3753 <varphone@qq.com>': '3627',
#           'Adam Duskett <aduskett@gmail.com>': '1951',
#           'Akkeoss <akeos@laposte.net>': '306',
#           'Alex Kaplan <alex@nextthing.co>': '333',
#           'Andrey Mihadyuk <maoi.by@gmail.com>': '675',
#           'Asaf Kahlon <asafka7@gmail.com>': '858',
#           'Austin Foxley <austin@axiim.com>': '233',
#           'Axel <axel.lin@gmail.com>': '425',
#           'Ayla <paul@crapouillou.net>': '1335',
#           'Ben Whitten <benwhitten@gmail.com>': '265',
#           'Benoît Thébaudeau <benoit@wsystem.com>': '203',
#           'Bernd Kuhls <berndkuhls@hotmail.com>': '11015',
#           'Bernd Kuhls <peter@korsgaard.com>': '303',
#           'Boris Krasnovskiy <boris.krasnovskiy@lairdconnect.com>': '597',
#           'Boris Krasnovskiy <boris.krasnovskiy@lairdtech.com>': '286',
#           'CI <fhunleth@troodon-software.com>': '601',
#           'Chris Gibson <cgibson@google.com>': '242',
#           'Chris Kuiper <ckuiper@google.com>': '218',
#           'D. Olsson <hi@senzilla.io>': '211',
#           'Daniel Mentz <danielmentz@google.com>': '288',
#           'Danomi Manchego <jacmet@sunsite.dk>': '707',
#           'David Barbion <dbarbion@gmail.com>': '1679',
#           'Denny Gentry <dgentry@google.com>': '1464',
#           'Denys Vlasenko <dvlasenk@redhat.com>': '487',
#           'Ed James <edjames@google.com>': '726',
#           'Eddie Cai <eddie.cai.linux@gmail.com>': '622',
#           'Erdi Chen <erdi@google.com>': '239',
#           'Eric Andersen <andersen@codepoet.org>': '5483',
#           'Eric First <efirst@google.com>': '314',
#           'Eric Le Bihan <eric.le.bihan.dev@free.fr>': '1334',
#           'Ezequiel <elezegarcia@gmail.com>': '418',
#           'Fabio Estevam <fabio.estevam@nxp.com>': '357',
#           'Fabrice Fontaine <fontaine.fabrice@gmail.com>': '8201',
#           'Fatih Aşıcı <fatih@pardus.org.tr>': '213',
#           'Flavio Castro <flcf@cesar.org.br>': '224',
#           'Frank Schütte <fschuett@gymhim.de>': '863',
#           'Gilles <gilles.talis@gmail.com>': '403',
#           'Giulio Benetti <giuliobenetti@micronovasrl.com>': '729',
#           'Guido <mtzguido@gmail.com>': '507',
#           'Guofeng <tgf.tang.guofeng@gmail.com>': '396',
#           'Gustavo Zacarias <gustavo@zacarias.com.ar>': '20433',
#           'Gustavo Zacarias <jacmet@sunsite.dk>': '1639',
#           'Gustavo Zacarias <peter@korsgaard.com>': '1553',
#           'Gwenhael <gwe@trabucayre.com>': '226',
#           'Hancock33 <63157658+Hancock33@users.noreply.github.com>': '750',
#           'Hans-Christian Egtvedt <hcegtvedt@atmel.com>': '334',
#           'HappyBasher <thomas@linuxmuster.net>': '365',
#           'HaseenaSainul <h.sainul@metrological.com>': '287',
#           'Heiko Thiery <heiko.thiery@gmail.com>': '317',
#           'Ian57 <yann@morere.eu>': '715',
#           'Ilia <ilia@mogilevsky.com.au>': '250',
#           'JB <wjblock@gmail.com>': '199',
#           'Jeremy <xgenetik57x@gmail.com>': '231',
#           'Jerome Pouiller <jezz@sysmic.org>': '384',
#           'Jerry Huang <jerry.huang@nxp.com>': '463',
#           'Jerzy Grzegorek <jerzy.grzegorek@trzebnica.net>': '816',
#           'Johan Oudinet <oudinet@cs.tum.edu>': '278',
#           'John Newlin <jnewlin@tsoft.com>': '724',
#           'John Voltz <john.voltz@gmail.com>': '516',
#           'João Cardoso <joao.fs.cardoso@gmail.com>': '3623',
#           'Jugurtha BELKALEM <jugurtha.belkalem@smile.fr>': '274',
#           'Juliano DOrigão <jdorigao@gmail.com>': '3201',
#           'Kurt Van Dijck <kurt@vandijck-laurijssen.be>': '227',
#           'Lio <lionel.bringuier@gmail.com>': '367',
#           'Lionel Landwerlin <llandwerlin@gmail.com>': '417',
#           'Liu Gang <Gang.Liu@nxp.com>': '281',
#           'Ludovic Desroches <desrochl@gmail.com>': '191',
#           'Maarten ter Huurne <maarten@treewalker.org>': '916',
#           'Marcin Niestroj <macius1990w@gmail.com>': '192',
#           'Mark Corbin <mark@balena.io>': '312',
#           'Martin Bark <martin@barkynet.com>': '625',
#           'Matt <brimstone@the.narro.ws>': '390',
#           'Matthew Fornero <mfornero@mathworks.com>': '702',
#           'Matthew Shyu <peter@korsgaard.com>': '467',
#           'Matthias Kaehlcke <mka@google.com>': '370',
#           'Maxime <maxime.hadjinlian@gmail.com>': '945',
#           'Maxime Ripard <maxime.ripard@anandra.org>': '494',
#           'Michael Baudino <michael@baudi.no>': '269',
#           'Ntemis <demetris@walla.com>': '609',
#           'OyyoDams <oyyodams@oyyodams.com>': '498',
#           'Ozgur <o.deveci@metrological.com>': '230',
#           'Peter Korsgaard <jacmet@sunsite.dk>': '22444',
#           'Peter Korsgaard <peter@korsgaard.com>': '8078',
#           'Peter S. Mazinger <ps.m@gmx.net>': '2677',
#           'Petr Vorel <pvorel@suse.cz>': '379',
#           'Philippe <phil@base-art.net>': '308',
#           'Pierre-Jean Texier <pjtexier@koncepto.io>': '373',
#           'Pit64 <webmaster@zelda-series.net>': '370',
#           'Pit64 <yrigaud@icloud.com>': '215',
#           'Rahul Bedarkar <Rahul.Bedarkar@imgtec.com>': '489',
#           'Reto Buerki <reet@codelabs.ch>': '858',
#           'Ricardo Martincoski <ricardo.martincoski@gmail.com>': '1327',
#           'Richard Frankel <rich@track.com>': '248',
#           'Romain <romain.naour@openwide.fr>': '3860',
#           'Romain TISSERAND <romain.tisserand@gmail.com>': '3045',
#           'Ryan Barnett <ryanbarnett3@gmail.com>': '189',
#           'Ryan Coe <bluemrp9@gmail.com>': '403',
#           'Samuel MARTIN <s.martin49@gmail.com>': '2270',
#           'Sergio Prado <sergiosiena@gmail.com>': '215',
#           'Service DevOps Buildserver <service.devops.buildserver@lairdtech.com>': '471',
#           'Shawn J. Goff <shawn7400@gmail.com>': '394',
#           'Shawn Ledbetter <sledbetter@google.com>': '486',
#           'Simon Dawson <spdawson@gmail.com>': '1085',
#           'Spenser Gilliland <spenserg@xilinx.com>': '315',
#           'Steve <steve@cozybit.com>': '495',
#           'Subs <Frog2wah@gmail.com>': '1072',
#           'Sven Neumann <neumann@teufel.de>': '950',
#           'Thomas De Schampheleire <patrickdepinguin+buildroot@gmail.com>': '387',
#           'Thomas De Schampheleire <patrickdepinguin@gmail.com>': '1501',
#           'Thomas Petazzoni <jacmet@sunsite.dk>': '1003',
#           'Thomas Petazzoni <peter@korsgaard.com>': '642',
#           'Thomas Petazzoni <thomas.petazzoni@bootlin.com>': '3153',
#           'Thomas Schmitt <schmitt@lmz-bw.de>': '255',
#           'Tiago <tcamargo@gmail.com>': '744',
#           'Unknown <liberodark@gmail.com>': '431',
#           'Vicente Olivert Riera <peter@korsgaard.com>': '190',
#           'Waldemar Brodkorb <wbx@uclibc-ng.org>': '328',
#           'Will Newton <willn@resin.io>': '349',
#           'Will Wagner <will_wagner@carallon.com>': '857',
#           'Yann E. MORIN <yann.morin.1998@anciens.enib.fr>': '470',
#           'Yann E. MORIN <yann.morin.1998@free.fr>': '8174',
#           'YibinLIU <beingly@gmail.com>': '259',
#           'Ziyuan <xzy.xu@rock-chips.com>': '232',
#           'a <Alexey.Brodkin@synopsys.com>': '660',
#           'a <Anton.Kolesov@synopsys.com>': '256',
#           'a <Artem.Bityutskiy@nokia.com>': '364',
#           'a <Fabio.Porcedda@gmail.com>': '772',
#           'a <Joakim.Tjernlund@transmode.se>': '223',
#           'a <Martin.Banky@gmail.com>': '271',
#           'a <Matthew.Weber@rockwellcollins.com>': '721',
#           'a <Mischa.Jonker@synopsys.com>': '273',
#           'albertd <albert@dahan.nl>': '3581',
#           'aldot <rep.dot.nop@gmail.com>': '4048',
#           'allannielsen <a@awn.dk>': '355',
#           'allanzhang <allanzhang@google.com>': '232',
#           'andersen <andersen@69ca8d6d-28ef-0310-b511-8ec308f3f277>': '2751',
#           'angeloc <angelo.compagnucci@gmail.com>': '511',
#           'aperez <aperez@igalia.com>': '563',
#           'ariel <ariel@vanguardiasur.com.ar>': '258',
#           'arne <arne@unicap-imaging.org>': '333',
#           'arnout <arnout@mind.be>': '2855',
#           'artemys <julien.boibessot@armadeus.com>': '229',
#           'baekdahl <jesper@baekdahl.dk>': '189',
#           'baruch <baruch@tkos.co.il>': '3453',
#           'bisson.gary <bisson.gary@gmail.com>': '487',
#           'bkg2k <bkg2k9@gmail.com>': '2079',
#           'bram oosterhuis <mail@bybram.com>': '813',
#           'carmelo.amoroso <carmelo.amoroso@st.com>': '465',
#           'ccrisan <ccrisan@gmail.com>': '2271',
#           'cedric <hello@cedric.ws>': '414',
#           'cfair <cfair@hach.com>': '623',
#           'correa <thiago.correa@gmail.com>': '316',
#           'croniccorey <corey.moyer@live.com>': '381',
#           'cyperghost <crcerror@users.noreply.github.com>': '358',
#           'daniel <daniel@caiaq.de>': '632',
#           'danieljlaird <danieljlaird@hotmail.com>': '270',
#           'david <cpasjuste@gmail.com>': '207',
#           'davilla <davilla@4pi.com>': '397',
#           'didin <didin@synopsys.com>': '223',
#           'elrafoon <ravas@tind.sk>': '520',
#           'etiennec <etienne.carriere@linaro.org>': '190',
#           'festevam <festevam@gmail.com>': '927',
#           'fperrad <francois.perrad@gadz.org>': '2736',
#           'g.portay <g.portay@overkiz.com>': '415',
#           'glebm <glebm@google.com>': '1030',
#           'guor <ren_guo@c-sky.com>': '857',
#           'hans-christian.egtvedt <hans-christian.egtvedt@atmel.com>': '917',
#           'haseenamol <haseenamol@tataelxsi.co.in>': '399',
#           'havelptess <patrick.havelange@tessares.net>': '419',
#           'hayavuk <hayavuk@gmail.com>': '289',
#           'hiro2233 <htakey@gmail.com>': '261',
#           'hmoffatt <hamish@cloud.net.au>': '237',
#           'hwoarang <hwoarang@gentoo.org>': '487',
#           'j1nx <p.steenbergen@j1nx.nl>': '221',
#           'jameshilliard <james.hilliard1@gmail.com>': '722',
#           'jasaw <jasaw@dius.com.au>': '323',
#           'jcmvbkbc <jcmvbkbc@gmail.com>': '469',
#           'jeffy <jeffy.chen@rock-chips.com>': '1183',
#           'jfthibert <jfthibert@google.com>': '754',
#           'jkrause <jkrause@posteo.de>': '1445',
#           'jocke <jocke@69ca8d6d-28ef-0310-b511-8ec308f3f277>': '197',
#           'joe.conley <joe.conley@lairdtech.com>': '544',
#           'jon <jon.hefling@lairdtech.com>': '372',
#           'kedong <kedong@google.com>': '616',
#           'khilman <khilman@linaro.org>': '238',
#           'lns <matzeton@googlemail.com>': '256',
#           'luca <luca@lucaceresoli.net>': '945',
#           'lucz <chongzhi_lu@c-sky.com>': '192',
#           'maoh <han_mao@c-sky.com>': '290',
#           'mhennerich <michael.hennerich@analog.com>': '439',
#           'mjn3 <mjn3@69ca8d6d-28ef-0310-b511-8ec308f3f277>': '419',
#           'mjn3 <mjn3@codepoet.org>': '725',
#           'mmayer <mmayer@broadcom.com>': '411',
#           'msieben <github@desiderium.eu>': '526',
#           'nerv <nerv@dawncrow.de>': '212',
#           'nicolas <nicolas.adenis.lamarre@gmail.com>': '5151',
#           'ninoh-fox <ninoh-fox@debian>': '460',
#           'nkukard <nkukard@lbsd.net>': '315',
#           'paradadf <paradad@outlook.com>': '2484',
#           'paulius.zaleckas <paulius.zaleckas@gmail.com>': '1610',
#           'pgynther <pgynther@google.com>': '223',
#           'pierre <pierre@wielders.net>': '583',
#           'ps.report <ps.report@gmx.net>': '2076',
#           'psm <psm@69ca8d6d-28ef-0310-b511-8ec308f3f277>': '840',
#           'richard <richard.kunze@web.de>': '383',
#           'robert <robert@openbsd.org>': '830',
#           'rockaddicted <nirvana_paradize@hotmail.com>': '329',
#           'root <kidovate@gmail.com>': '10187',
#           'root <woutermeek@gmail.com>': '237',
#           's.neumann <s.neumann@raumfeld.com>': '2430',
#           'sagaertj <sagaert.johan@skynet.be>': '191',
#           'scott <scott@quad.(none)>': '437',
#           'sddddd s <digitallumberjack@gmail.com>': '2659',
#           'sean meng <sean.meng@lairdtech.com>': '328',
#           'sjhill <sjhill@realitydiluted.com>': '1227',
#           'ski7777 <r.jacob2002@gmail.com>': '478',
#           'smcgruer <smcgruer@google.com>': '246',
#           'sonicz921 <sonic.zhang@analog.com>': '583',
#           'strodown <strodown@gmail.com>': '850',
#           'the-hydra <xphile@gmx.us>': '208',
#           'till <till@harbaum.org>': '263',
#           'tyrantyr <fabiorush@gmail.com>': '196',
#           'ulf.samuelsson <ulf.samuelsson@atmel.com>': '3513',
#           'unixmania <unixmania@gmail.com>': '471',
#           'vapier <vapier@69ca8d6d-28ef-0310-b511-8ec308f3f277>': '1571',
#           'vapier <vapier@gentoo.org>': '3511',
#           'vgupta <vgupta@synopsys.com>': '251',
#           'vicent.chi <vicent.chi@rock-chips.com>': '213',
#           'vladimiroltean <olteanv@gmail.com>': '341',
#           'vriera <Vincent.Riera@imgtec.com>': '2410',
#           'wbx <wbx@openadk.org>': '1220',
#           'wouterlucas <wouter@wouterlucas.com>': '558',
#           'wxt <wxt@rock-chips.com>': '397',
#           'wzz <wzz@rock-chips.com>': '260',
#           'yegor_sub1 <yegor_sub1@visionsystems.de>': '238',
#           'yegorslists <yegorslists@googlemail.com>': '1926',
#           'zdobersek <zdobersek@igalia.com>': '559'},
#  'EarliestCommitDate': 958277795,
#  'FileInfo': {'Basic': 18,
#               'C/C++': 249998,
#               'Cobol': 1,
#               'Dart': 1,
#               'Go': 50,
#               'Java': 250,
#               'JavaScript': 1678,
#               'Lua': 198,
#               'PHP': 514,
#               'Perl': 2826,
#               'Python': 8928,
#               'Ruby': 5,
#               'Rust': 2087,
#               'Sql': 90,
#               'Swift': 15,
#               'TypeScript': 26,
#               'fml': 86,
#               'other': 337777},
#  'Gender': {'female': 199, 'male': 3457},
#  'LatestCommitDate': 1637721166,
#  'MonNauth': {'2000-05': 2,
#               '2000-06': 4,
#               '2000-07': 4,
#               '2000-08': 4,
#               '2000-09': 4,
#               '2000-10': 2,
#               '2000-11': 2,
#               '2000-12': 2,
#               '2001-01': 6,
#               '2001-02': 6,
#               '2001-03': 8,
#               '2001-04': 4,
#               '2001-05': 8,
#               '2001-06': 8,
#               '2001-07': 8,
#               '2001-08': 6,
#               '2001-09': 4,
#               '2001-10': 6,
#               '2001-11': 6,
#               '2001-12': 6,
#               '2002-01': 5,
#               '2002-02': 8,
#               '2002-03': 8,
#               '2002-04': 10,
#               '2002-05': 6,
#               '2002-06': 6,
#               '2002-07': 8,
#               '2002-08': 14,
#               '2002-09': 12,
#               '2002-10': 8,
#               '2002-11': 12,
#               '2002-12': 10,
#               '2003-01': 8,
#               '2003-02': 8,
#               '2003-03': 8,
#               '2003-04': 6,
#               '2003-05': 8,
#               '2003-06': 4,
#               '2003-07': 4,
#               '2003-08': 9,
#               '2003-09': 9,
#               '2003-10': 11,
#               '2003-11': 7,
#               '2003-12': 5,
#               '2004-01': 7,
#               '2004-02': 5,
#               '2004-03': 6,
#               '2004-04': 5,
#               '2004-05': 8,
#               '2004-06': 2,
#               '2004-07': 4,
#               '2004-08': 6,
#               '2004-09': 8,
#               '2004-10': 12,
#               '2004-11': 10,
#               '2004-12': 6,
#               '2005-01': 10,
#               '2005-02': 12,
#               '2005-03': 14,
#               '2005-04': 18,
#               '2005-05': 16,
#               '2005-06': 11,
#               '2005-07': 12,
#               '2005-08': 11,
#               '2005-09': 13,
#               '2005-10': 11,
#               '2005-11': 13,
#               '2005-12': 13,
#               '2006-01': 13,
#               '2006-02': 12,
#               '2006-03': 11,
#               '2006-04': 9,
#               '2006-05': 12,
#               '2006-06': 13,
#               '2006-07': 11,
#               '2006-08': 18,
#               '2006-09': 9,
#               '2006-10': 13,
#               '2006-11': 14,
#               '2006-12': 15,
#               '2007-01': 14,
#               '2007-02': 20,
#               '2007-03': 20,
#               '2007-04': 15,
#               '2007-05': 15,
#               '2007-06': 12,
#               '2007-07': 12,
#               '2007-08': 12,
#               '2007-09': 15,
#               '2007-10': 12,
#               '2007-11': 19,
#               '2007-12': 15,
#               '2008-01': 21,
#               '2008-02': 23,
#               '2008-03': 22,
#               '2008-04': 18,
#               '2008-05': 20,
#               '2008-06': 21,
#               '2008-07': 14,
#               '2008-08': 19,
#               '2008-09': 20,
#               '2008-10': 19,
#               '2008-11': 23,
#               '2008-12': 18,
#               '2009-01': 15,
#               '2009-02': 19,
#               '2009-03': 18,
#               '2009-04': 15,
#               '2009-05': 37,
#               '2009-06': 38,
#               '2009-07': 48,
#               '2009-08': 34,
#               '2009-09': 41,
#               '2009-10': 37,
#               '2009-11': 36,
#               '2009-12': 43,
#               '2010-01': 37,
#               '2010-02': 39,
#               '2010-03': 35,
#               '2010-04': 59,
#               '2010-05': 50,
#               '2010-06': 52,
#               '2010-07': 50,
#               '2010-08': 40,
#               '2010-09': 48,
#               '2010-10': 38,
#               '2010-11': 61,
#               '2010-12': 55,
#               '2011-01': 42,
#               '2011-02': 56,
#               '2011-03': 57,
#               '2011-04': 48,
#               '2011-05': 58,
#               '2011-06': 50,
#               '2011-07': 68,
#               '2011-08': 51,
#               '2011-09': 57,
#               '2011-10': 74,
#               '2011-11': 68,
#               '2011-12': 53,
#               '2012-01': 74,
#               '2012-02': 85,
#               '2012-03': 98,
#               '2012-04': 88,
#               '2012-05': 84,
#               '2012-06': 101,
#               '2012-07': 92,
#               '2012-08': 103,
#               '2012-09': 89,
#               '2012-10': 115,
#               '2012-11': 127,
#               '2012-12': 114,
#               '2013-01': 139,
#               '2013-02': 139,
#               '2013-03': 160,
#               '2013-04': 126,
#               '2013-05': 147,
#               '2013-06': 136,
#               '2013-07': 134,
#               '2013-08': 146,
#               '2013-09': 156,
#               '2013-10': 165,
#               '2013-11': 162,
#               '2013-12': 186,
#               '2014-01': 183,
#               '2014-02': 198,
#               '2014-03': 182,
#               '2014-04': 216,
#               '2014-05': 192,
#               '2014-06': 207,
#               '2014-07': 205,
#               '2014-08': 179,
#               '2014-09': 204,
#               '2014-10': 233,
#               '2014-11': 187,
#               '2014-12': 198,
#               '2015-01': 210,
#               '2015-02': 241,
#               '2015-03': 283,
#               '2015-04': 254,
#               '2015-05': 230,
#               '2015-06': 220,
#               '2015-07': 294,
#               '2015-08': 221,
#               '2015-09': 237,
#               '2015-10': 295,
#               '2015-11': 267,
#               '2015-12': 247,
#               '2016-01': 252,
#               '2016-02': 278,
#               '2016-03': 294,
#               '2016-04': 270,
#               '2016-05': 236,
#               '2016-06': 203,
#               '2016-07': 222,
#               '2016-08': 190,
#               '2016-09': 180,
#               '2016-10': 176,
#               '2016-11': 203,
#               '2016-12': 193,
#               '2017-01': 218,
#               '2017-02': 195,
#               '2017-03': 212,
#               '2017-04': 185,
#               '2017-05': 202,
#               '2017-06': 192,
#               '2017-07': 225,
#               '2017-08': 181,
#               '2017-09': 213,
#               '2017-10': 200,
#               '2017-11': 229,
#               '2017-12': 183,
#               '2018-01': 222,
#               '2018-02': 182,
#               '2018-03': 209,
#               '2018-04': 216,
#               '2018-05': 234,
#               '2018-06': 219,
#               '2018-07': 229,
#               '2018-08': 240,
#               '2018-09': 228,
#               '2018-10': 228,
#               '2018-11': 227,
#               '2018-12': 202,
#               '2019-01': 243,
#               '2019-02': 215,
#               '2019-03': 222,
#               '2019-04': 221,
#               '2019-05': 191,
#               '2019-06': 197,
#               '2019-07': 207,
#               '2019-08': 205,
#               '2019-09': 230,
#               '2019-10': 238,
#               '2019-11': 224,
#               '2019-12': 198,
#               '2020-01': 213,
#               '2020-02': 235,
#               '2020-03': 251,
#               '2020-04': 224,
#               '2020-05': 216,
#               '2020-06': 215,
#               '2020-07': 214,
#               '2020-08': 174,
#               '2020-09': 181,
#               '2020-10': 189,
#               '2020-11': 176,
#               '2020-12': 168,
#               '2021-01': 177,
#               '2021-02': 174,
#               '2021-03': 157,
#               '2021-04': 133,
#               '2021-05': 152,
#               '2021-06': 151,
#               '2021-07': 125,
#               '2021-08': 157,
#               '2021-09': 140,
#               '2021-10': 127,
#               '2021-11': 76},
#  'MonNcmt': {'2000-05': 22,
#              '2000-06': 10,
#              '2000-07': 38,
#              '2000-08': 14,
#              '2000-09': 8,
#              '2000-10': 196,
#              '2000-11': 38,
#              '2000-12': 18,
#              '2001-01': 184,
#              '2001-02': 148,
#              '2001-03': 136,
#              '2001-04': 154,
#              '2001-05': 256,
#              '2001-06': 182,
#              '2001-07': 154,
#              '2001-08': 106,
#              '2001-09': 56,
#              '2001-10': 72,
#              '2001-11': 178,
#              '2001-12': 68,
#              '2002-01': 234,
#              '2002-02': 270,
#              '2002-03': 226,
#              '2002-04': 194,
#              '2002-05': 178,
#              '2002-06': 154,
#              '2002-07': 228,
#              '2002-08': 424,
#              '2002-09': 134,
#              '2002-10': 140,
#              '2002-11': 352,
#              '2002-12': 116,
#              '2003-01': 392,
#              '2003-02': 208,
#              '2003-03': 152,
#              '2003-04': 30,
#              '2003-05': 32,
#              '2003-06': 228,
#              '2003-07': 34,
#              '2003-08': 172,
#              '2003-09': 306,
#              '2003-10': 178,
#              '2003-11': 400,
#              '2003-12': 178,
#              '2004-01': 200,
#              '2004-02': 206,
#              '2004-03': 98,
#              '2004-04': 70,
#              '2004-05': 94,
#              '2004-06': 48,
#              '2004-07': 98,
#              '2004-08': 166,
#              '2004-09': 132,
#              '2004-10': 342,
#              '2004-11': 70,
#              '2004-12': 144,
#              '2005-01': 200,
#              '2005-02': 278,
#              '2005-03': 208,
#              '2005-04': 195,
#              '2005-05': 246,
#              '2005-06': 367,
#              '2005-07': 374,
#              '2005-08': 467,
#              '2005-09': 478,
#              '2005-10': 377,
#              '2005-11': 832,
#              '2005-12': 688,
#              '2006-01': 1273,
#              '2006-02': 909,
#              '2006-03': 322,
#              '2006-04': 251,
#              '2006-05': 112,
#              '2006-06': 244,
#              '2006-07': 263,
#              '2006-08': 272,
#              '2006-09': 109,
#              '2006-10': 113,
#              '2006-11': 289,
#              '2006-12': 599,
#              '2007-01': 788,
#              '2007-02': 459,
#              '2007-03': 274,
#              '2007-04': 169,
#              '2007-05': 215,
#              '2007-06': 404,
#              '2007-07': 916,
#              '2007-08': 855,
#              '2007-09': 882,
#              '2007-10': 368,
#              '2007-11': 352,
#              '2007-12': 125,
#              '2008-01': 277,
#              '2008-02': 205,
#              '2008-03': 944,
#              '2008-04': 556,
#              '2008-05': 315,
#              '2008-06': 675,
#              '2008-07': 796,
#              '2008-08': 808,
#              '2008-09': 650,
#              '2008-10': 748,
#              '2008-11': 523,
#              '2008-12': 1165,
#              '2009-01': 2356,
#              '2009-02': 658,
#              '2009-03': 1201,
#              '2009-04': 522,
#              '2009-05': 493,
#              '2009-06': 460,
#              '2009-07': 1257,
#              '2009-08': 672,
#              '2009-09': 816,
#              '2009-10': 1311,
#              '2009-11': 981,
#              '2009-12': 1012,
#              '2010-01': 468,
#              '2010-02': 2282,
#              '2010-03': 1184,
#              '2010-04': 1391,
#              '2010-05': 1395,
#              '2010-06': 964,
#              '2010-07': 1484,
#              '2010-08': 526,
#              '2010-09': 1488,
#              '2010-10': 833,
#              '2010-11': 1172,
#              '2010-12': 1612,
#              '2011-01': 1040,
#              '2011-02': 1158,
#              '2011-03': 1949,
#              '2011-04': 1922,
#              '2011-05': 1132,
#              '2011-06': 650,
#              '2011-07': 1446,
#              '2011-08': 1093,
#              '2011-09': 1421,
#              '2011-10': 1621,
#              '2011-11': 1181,
#              '2011-12': 1050,
#              '2012-01': 1997,
#              '2012-02': 1667,
#              '2012-03': 1935,
#              '2012-04': 1819,
#              '2012-05': 2460,
#              '2012-06': 2705,
#              '2012-07': 1798,
#              '2012-08': 1950,
#              '2012-09': 2375,
#              '2012-10': 2029,
#              '2012-11': 2714,
#              '2012-12': 2609,
#              '2013-01': 2649,
#              '2013-02': 1806,
#              '2013-03': 2443,
#              '2013-04': 1978,
#              '2013-05': 2960,
#              '2013-06': 2380,
#              '2013-07': 1686,
#              '2013-08': 1436,
#              '2013-09': 2140,
#              '2013-10': 2621,
#              '2013-11': 2250,
#              '2013-12': 2863,
#              '2014-01': 2852,
#              '2014-02': 3284,
#              '2014-03': 3354,
#              '2014-04': 3029,
#              '2014-05': 2830,
#              '2014-06': 3904,
#              '2014-07': 2990,
#              '2014-08': 2478,
#              '2014-09': 2417,
#              '2014-10': 3353,
#              '2014-11': 2334,
#              '2014-12': 2137,
#              '2015-01': 2150,
#              '2015-02': 2743,
#              '2015-03': 3564,
#              '2015-04': 3758,
#              '2015-05': 2213,
#              '2015-06': 2364,
#              '2015-07': 4143,
#              '2015-08': 1911,
#              '2015-09': 2018,
#              '2015-10': 3003,
#              '2015-11': 2799,
#              '2015-12': 3044,
#              '2016-01': 2514,
#              '2016-02': 2777,
#              '2016-03': 3227,
#              '2016-04': 2645,
#              '2016-05': 2489,
#              '2016-06': 3076,
#              '2016-07': 2945,
#              '2016-08': 1995,
#              '2016-09': 2302,
#              '2016-10': 3450,
#              '2016-11': 2620,
#              '2016-12': 2834,
#              '2017-01': 2868,
#              '2017-02': 3486,
#              '2017-03': 4054,
#              '2017-04': 2900,
#              '2017-05': 2781,
#              '2017-06': 2763,
#              '2017-07': 3917,
#              '2017-08': 1947,
#              '2017-09': 2967,
#              '2017-10': 2179,
#              '2017-11': 2327,
#              '2017-12': 1677,
#              '2018-01': 2384,
#              '2018-02': 1886,
#              '2018-03': 2433,
#              '2018-04': 1968,
#              '2018-05': 2168,
#              '2018-06': 1951,
#              '2018-07': 2523,
#              '2018-08': 2892,
#              '2018-09': 2753,
#              '2018-10': 2459,
#              '2018-11': 1978,
#              '2018-12': 2180,
#              '2019-01': 2657,
#              '2019-02': 2145,
#              '2019-03': 2405,
#              '2019-04': 2315,
#              '2019-05': 2042,
#              '2019-06': 1866,
#              '2019-07': 2095,
#              '2019-08': 2275,
#              '2019-09': 2238,
#              '2019-10': 2406,
#              '2019-11': 2570,
#              '2019-12': 2525,
#              '2020-01': 2302,
#              '2020-02': 2312,
#              '2020-03': 2536,
#              '2020-04': 2849,
#              '2020-05': 2619,
#              '2020-06': 3311,
#              '2020-07': 2621,
#              '2020-08': 4725,
#              '2020-09': 1978,
#              '2020-10': 2262,
#              '2020-11': 3980,
#              '2020-12': 2409,
#              '2021-01': 2686,
#              '2021-02': 2142,
#              '2021-03': 2257,
#              '2021-04': 1883,
#              '2021-05': 2510,
#              '2021-06': 1956,
#              '2021-07': 1980,
#              '2021-08': 2143,
#              '2021-09': 2325,
#              '2021-10': 1842,
#              '2021-11': 713},
#  'NumActiveMon': 259,
#  'NumAuthors': 4347,
#  'NumBlobs': 694969,
#  'NumCommits': 375883,
#  'NumCore': 239,
#  'NumFiles': 604548,
#  'NumForks': 4390,
#  'NumStars': 12124,
#  'ProjectID': 'buildroot_buildroot',
#  'RootFork': 'buildroot_buildroot',
#  '_id': ObjectId('628ee344f7956706ea28f874')}

# %% [markdown]
# Let's select simple metadata

# %%
pprint.pprint(coll.find_one({'ProjectID': project},
                            {'_id': 0, 'CommunitySize': 1, 'NumCore': 1,
                             'EarliestCommitDate': 1, 'LatestCommitDate': 1,
                             'NumActiveMon': 1,
                             'NumAuthors': 1,
                             'NumBlobs': 1,
                             'NumCommits': 1,
                             'NumFiles': 1,
                             'NumForks': 1,
                             'NumStars': 1,
                             'ProjectID': 1,
                             'RootFork': 1,
                            }))
# Out:
# {'CommunitySize': 4897,
#  'EarliestCommitDate': 958277795,
#  'LatestCommitDate': 1637721166,
#  'NumActiveMon': 259,
#  'NumAuthors': 4347,
#  'NumBlobs': 694969,
#  'NumCommits': 375883,
#  'NumCore': 239,
#  'NumFiles': 604548,
#  'NumForks': 4390,
#  'NumStars': 12124,
#  'ProjectID': 'buildroot_buildroot',
#  'RootFork': 'buildroot_buildroot'}

# %%
project='salsa.debian.org_security-tracker-team_security-tracker'
pprint.pprint(coll.find_one({'ProjectID': project}))
# Out:
# {'ApiInfo': {'PY:': 1144,
#              'PY:BaseHTTPServer': 41,
#              'PY:F401': 6,
#              'PY:SOAPpy': 12,
#              'PY:SocketServer': 41,
#              'PY:__future__.print_function': 135,
#              'PY:__future__.with_statement': 43,
#              'PY:apsw': 247,
#              'PY:apt_pkg': 100,
#              'PY:apt_pkg.version_compare': 105,
#              'PY:argparse': 80,
#              'PY:base64': 200,
#              'PY:bin.tracker_data.TrackerData': 3,
#              'PY:bugs': 517,
#              'PY:bz2': 25,
#              'PY:cPickle': 213,
#              'PY:cStringIO': 265,
#              'PY:cStringIO.StringIO': 41,
#              'PY:cgi': 64,
#              'PY:cjson': 16,
#              'PY:collections': 61,
#              'PY:collections.OrderedDict': 6,
#              'PY:collections.namedtuple': 135,
#              'PY:config': 128,
#              'PY:datetime': 34,
#              'PY:datetime.datetime': 31,
#              'PY:dateutil.relativedelta': 18,
#              'PY:debian.deb822.Sources': 17,
#              'PY:debian.debian_support.Version': 16,
#              'PY:debian_support': 466,
#              'PY:debian_support.PointUpdateParser': 11,
#              'PY:dist_config': 132,
#              'PY:email.utils': 59,
#              'PY:errno': 17,
#              'PY:eventlet': 14,
#              'PY:fileinput': 9,
#              'PY:functools': 25,
#              'PY:getopt': 2,
#              'PY:glob': 256,
#              'PY:grp': 64,
#              'PY:gzip': 105,
#              'PY:hashlib': 85,
#              'PY:helpers.isstring': 65,
#              'PY:httplib': 4,
#              'PY:io': 14,
#              'PY:io.StringIO': 6,
#              'PY:itertools': 105,
#              'PY:json': 252,
#              'PY:keyword.iskeyword': 4,
#              'PY:lzma': 4,
#              'PY:noqa': 10,
#              'PY:noqa:': 6,
#              'PY:noqa:F401': 2,
#              'PY:operator': 11,
#              'PY:operator.itemgetter': 4,
#              'PY:os': 510,
#              'PY:os.path': 333,
#              'PY:pickle': 48,
#              'PY:pwd.getpwuid': 8,
#              'PY:python3.cmp': 6,
#              'PY:re': 936,
#              'PY:regexpcase': 4,
#              'PY:requests': 49,
#              'PY:secmaster': 8,
#              'PY:sectracker.analyzers': 17,
#              'PY:sectracker.diagnostics': 34,
#              'PY:sectracker.diagnostics.Diagnostics': 19,
#              'PY:sectracker.parsers': 69,
#              'PY:sectracker.regexpcase': 33,
#              'PY:sectracker.repo': 8,
#              'PY:sectracker.repo.Config': 14,
#              'PY:sectracker.xcollections.namedtuple': 27,
#              'PY:sectracker.xpickle': 56,
#              'PY:sectracker.xpickle.safeunlink': 15,
#              'PY:security_db': 269,
#              'PY:setup_paths': 27,
#              'PY:sha': 18,
#              'PY:shutil': 10,
#              'PY:six': 25,
#              'PY:socket': 64,
#              'PY:string': 11,
#              'PY:struct': 64,
#              'PY:subprocess': 50,
#              'PY:sys': 763,
#              'PY:sys.intern': 2,
#              'PY:tempfile': 123,
#              'PY:threading': 53,
#              'PY:time': 67,
#              'PY:traceback': 64,
#              'PY:tracker_data.TrackerData': 61,
#              'PY:types': 448,
#              'PY:unittest': 2,
#              'PY:unsupported_packages.UnsupportedPackages': 31,
#              'PY:urllib': 79,
#              'PY:urllib2': 46,
#              'PY:web_support': 258,
#              'PY:xcollections': 5,
#              'PY:xml.sax': 10,
#              'PY:xml.sax.handler': 10,
#              'PY:xpickle': 6,
#              'PY:yaml': 2,
#              'PY:zlib': 200},
#  'BlobCommunitySize': '2',
#  'BlobParent': 'gitorious.org_security-tracker/security-tracker',
#  'CommunitySize': 27,
#  'Core': {'Emilio Pozuelo Monfort <pochu@debian.org>': '2581',
#           'Markus Koschany <apo@debian.org>': '4406',
#           'Moritz <jmm@debian.org>': '25993',
#           'Nico Golde <nion@debian.org>': '4898',
#           'Steffen Joeris <white>': '2206',
#           'Thijs <thijs@debian.org>': '2952',
#           'Thorsten Alteholz <debian@alteholz.de>': '3561',
#           'carnil <carnil@cpan.org>': '76598',
#           'fw <fw@deneb.enyo.de>': '2996',
#           'henri <henri@nerv.fi>': '4045',
#           'joey <joey@kitenet.net>': '7461',
#           'lamby <lamby@debian.org>': '4439',
#           'security tracker role <sectracker@debian.org>': '7887'},
#  'EarliestCommitDate': 1098910404,
#  'FileInfo': {'Go': 1,
#               'JavaScript': 4,
#               'Lisp': 1,
#               'Perl': 4,
#               'Python': 51,
#               'other': 483},
#  'Gender': {'female': 5, 'male': 207},
#  'LatestCommitDate': 1637978885,
#  'MonNauth': {'2004-10': 8,
#               '2004-11': 6,
#               '2004-12': 3,
#               '2005-01': 3,
#               '2005-02': 4,
#               '2005-03': 6,
#               '2005-04': 5,
#               '2005-05': 5,
#               '2005-06': 4,
#               '2005-07': 5,
#               '2005-08': 8,
#               '2005-09': 9,
#               '2005-10': 8,
#               '2005-11': 7,
#               '2005-12': 6,
#               '2006-01': 6,
#               '2006-02': 6,
#               '2006-03': 7,
#               '2006-04': 6,
#               '2006-05': 8,
#               '2006-06': 8,
#               '2006-07': 7,
#               '2006-08': 7,
#               '2006-09': 6,
#               '2006-10': 7,
#               '2006-11': 7,
#               '2006-12': 7,
#               '2007-01': 12,
#               '2007-02': 12,
#               '2007-03': 11,
#               '2007-04': 8,
#               '2007-05': 15,
#               '2007-06': 10,
#               '2007-07': 10,
#               '2007-08': 10,
#               '2007-09': 10,
#               '2007-10': 11,
#               '2007-11': 11,
#               '2007-12': 14,
#               '2008-01': 10,
#               '2008-02': 8,
#               '2008-03': 9,
#               '2008-04': 10,
#               '2008-05': 13,
#               '2008-06': 13,
#               '2008-07': 13,
#               '2008-08': 10,
#               '2008-09': 13,
#               '2008-10': 12,
#               '2008-11': 14,
#               '2008-12': 13,
#               '2009-01': 14,
#               '2009-02': 12,
#               '2009-03': 13,
#               '2009-04': 11,
#               '2009-05': 15,
#               '2009-06': 13,
#               '2009-07': 15,
#               '2009-08': 15,
#               '2009-09': 13,
#               '2009-10': 13,
#               '2009-11': 11,
#               '2009-12': 15,
#               '2010-01': 15,
#               '2010-02': 14,
#               '2010-03': 12,
#               '2010-04': 13,
#               '2010-05': 12,
#               '2010-06': 13,
#               '2010-07': 14,
#               '2010-08': 17,
#               '2010-09': 16,
#               '2010-10': 14,
#               '2010-11': 13,
#               '2010-12': 13,
#               '2011-01': 17,
#               '2011-02': 18,
#               '2011-03': 16,
#               '2011-04': 16,
#               '2011-05': 13,
#               '2011-06': 18,
#               '2011-07': 16,
#               '2011-08': 15,
#               '2011-09': 19,
#               '2011-10': 17,
#               '2011-11': 14,
#               '2011-12': 16,
#               '2012-01': 17,
#               '2012-02': 15,
#               '2012-03': 20,
#               '2012-04': 19,
#               '2012-05': 20,
#               '2012-06': 17,
#               '2012-07': 14,
#               '2012-08': 18,
#               '2012-09': 12,
#               '2012-10': 14,
#               '2012-11': 17,
#               '2012-12': 10,
#               '2013-01': 16,
#               '2013-02': 25,
#               '2013-03': 15,
#               '2013-04': 16,
#               '2013-05': 18,
#               '2013-06': 16,
#               '2013-07': 17,
#               '2013-08': 14,
#               '2013-09': 19,
#               '2013-10': 14,
#               '2013-11': 12,
#               '2013-12': 17,
#               '2014-01': 15,
#               '2014-02': 18,
#               '2014-03': 15,
#               '2014-04': 18,
#               '2014-05': 15,
#               '2014-06': 19,
#               '2014-07': 22,
#               '2014-08': 21,
#               '2014-09': 24,
#               '2014-10': 22,
#               '2014-11': 25,
#               '2014-12': 26,
#               '2015-01': 25,
#               '2015-02': 26,
#               '2015-03': 26,
#               '2015-04': 27,
#               '2015-05': 27,
#               '2015-06': 29,
#               '2015-07': 23,
#               '2015-08': 22,
#               '2015-09': 23,
#               '2015-10': 27,
#               '2015-11': 21,
#               '2015-12': 22,
#               '2016-01': 27,
#               '2016-02': 26,
#               '2016-03': 21,
#               '2016-04': 24,
#               '2016-05': 29,
#               '2016-06': 20,
#               '2016-07': 31,
#               '2016-08': 29,
#               '2016-09': 32,
#               '2016-10': 32,
#               '2016-11': 32,
#               '2016-12': 32,
#               '2017-01': 30,
#               '2017-02': 27,
#               '2017-03': 26,
#               '2017-04': 24,
#               '2017-05': 23,
#               '2017-06': 28,
#               '2017-07': 27,
#               '2017-08': 27,
#               '2017-09': 29,
#               '2017-10': 27,
#               '2017-11': 33,
#               '2017-12': 32,
#               '2018-01': 33,
#               '2018-02': 33,
#               '2018-03': 32,
#               '2018-04': 28,
#               '2018-05': 32,
#               '2018-06': 26,
#               '2018-07': 29,
#               '2018-08': 28,
#               '2018-09': 29,
#               '2018-10': 29,
#               '2018-11': 29,
#               '2018-12': 26,
#               '2019-01': 32,
#               '2019-02': 29,
#               '2019-03': 33,
#               '2019-04': 29,
#               '2019-05': 28,
#               '2019-06': 23,
#               '2019-07': 24,
#               '2019-08': 27,
#               '2019-09': 30,
#               '2019-10': 28,
#               '2019-11': 34,
#               '2019-12': 26,
#               '2020-01': 29,
#               '2020-02': 33,
#               '2020-03': 31,
#               '2020-04': 27,
#               '2020-05': 28,
#               '2020-06': 24,
#               '2020-07': 24,
#               '2020-08': 25,
#               '2020-09': 22,
#               '2020-10': 21,
#               '2020-11': 26,
#               '2020-12': 25,
#               '2021-01': 24,
#               '2021-02': 32,
#               '2021-03': 25,
#               '2021-04': 29,
#               '2021-05': 26,
#               '2021-06': 21,
#               '2021-07': 23,
#               '2021-08': 21,
#               '2021-09': 24,
#               '2021-10': 23,
#               '2021-11': 28},
#  'MonNcmt': {'2004-10': 52,
#              '2004-11': 103,
#              '2004-12': 69,
#              '2005-01': 107,
#              '2005-02': 173,
#              '2005-03': 206,
#              '2005-04': 231,
#              '2005-05': 241,
#              '2005-06': 229,
#              '2005-07': 386,
#              '2005-08': 488,
#              '2005-09': 1006,
#              '2005-10': 746,
#              '2005-11': 556,
#              '2005-12': 576,
#              '2006-01': 414,
#              '2006-02': 296,
#              '2006-03': 356,
#              '2006-04': 348,
#              '2006-05': 408,
#              '2006-06': 434,
#              '2006-07': 312,
#              '2006-08': 360,
#              '2006-09': 256,
#              '2006-10': 234,
#              '2006-11': 262,
#              '2006-12': 340,
#              '2007-01': 378,
#              '2007-02': 208,
#              '2007-03': 220,
#              '2007-04': 294,
#              '2007-05': 400,
#              '2007-06': 248,
#              '2007-07': 254,
#              '2007-08': 506,
#              '2007-09': 572,
#              '2007-10': 840,
#              '2007-11': 568,
#              '2007-12': 654,
#              '2008-01': 580,
#              '2008-02': 370,
#              '2008-03': 422,
#              '2008-04': 392,
#              '2008-05': 590,
#              '2008-06': 492,
#              '2008-07': 572,
#              '2008-08': 466,
#              '2008-09': 380,
#              '2008-10': 620,
#              '2008-11': 690,
#              '2008-12': 538,
#              '2009-01': 580,
#              '2009-02': 332,
#              '2009-03': 458,
#              '2009-04': 470,
#              '2009-05': 500,
#              '2009-06': 470,
#              '2009-07': 440,
#              '2009-08': 536,
#              '2009-09': 376,
#              '2009-10': 502,
#              '2009-11': 496,
#              '2009-12': 564,
#              '2010-01': 588,
#              '2010-02': 356,
#              '2010-03': 410,
#              '2010-04': 416,
#              '2010-05': 390,
#              '2010-06': 340,
#              '2010-07': 288,
#              '2010-08': 320,
#              '2010-09': 320,
#              '2010-10': 270,
#              '2010-11': 180,
#              '2010-12': 282,
#              '2011-01': 500,
#              '2011-02': 490,
#              '2011-03': 394,
#              '2011-04': 298,
#              '2011-05': 256,
#              '2011-06': 252,
#              '2011-07': 366,
#              '2011-08': 202,
#              '2011-09': 376,
#              '2011-10': 392,
#              '2011-11': 376,
#              '2011-12': 458,
#              '2012-01': 798,
#              '2012-02': 428,
#              '2012-03': 460,
#              '2012-04': 622,
#              '2012-05': 578,
#              '2012-06': 470,
#              '2012-07': 428,
#              '2012-08': 456,
#              '2012-09': 374,
#              '2012-10': 340,
#              '2012-11': 302,
#              '2012-12': 398,
#              '2013-01': 652,
#              '2013-02': 714,
#              '2013-03': 666,
#              '2013-04': 624,
#              '2013-05': 656,
#              '2013-06': 728,
#              '2013-07': 714,
#              '2013-08': 682,
#              '2013-09': 680,
#              '2013-10': 810,
#              '2013-11': 524,
#              '2013-12': 974,
#              '2014-01': 926,
#              '2014-02': 916,
#              '2014-03': 934,
#              '2014-04': 770,
#              '2014-05': 630,
#              '2014-06': 924,
#              '2014-07': 982,
#              '2014-08': 992,
#              '2014-09': 1292,
#              '2014-10': 1202,
#              '2014-11': 1382,
#              '2014-12': 1200,
#              '2015-01': 1630,
#              '2015-02': 1350,
#              '2015-03': 1498,
#              '2015-04': 1370,
#              '2015-05': 1266,
#              '2015-06': 1268,
#              '2015-07': 1114,
#              '2015-08': 1152,
#              '2015-09': 1070,
#              '2015-10': 1112,
#              '2015-11': 1044,
#              '2015-12': 1244,
#              '2016-01': 1524,
#              '2016-02': 1378,
#              '2016-03': 1228,
#              '2016-04': 1272,
#              '2016-05': 1768,
#              '2016-06': 1448,
#              '2016-07': 1508,
#              '2016-08': 1128,
#              '2016-09': 1400,
#              '2016-10': 1730,
#              '2016-11': 1710,
#              '2016-12': 1922,
#              '2017-01': 2020,
#              '2017-02': 1370,
#              '2017-03': 1820,
#              '2017-04': 1960,
#              '2017-05': 1908,
#              '2017-06': 1772,
#              '2017-07': 2182,
#              '2017-08': 2398,
#              '2017-09': 1914,
#              '2017-10': 1774,
#              '2017-11': 1946,
#              '2017-12': 1985,
#              '2018-01': 1914,
#              '2018-02': 1850,
#              '2018-03': 2030,
#              '2018-04': 1792,
#              '2018-05': 1686,
#              '2018-06': 2279,
#              '2018-07': 2867,
#              '2018-08': 2193,
#              '2018-09': 2174,
#              '2018-10': 2204,
#              '2018-11': 2398,
#              '2018-12': 2308,
#              '2019-01': 2307,
#              '2019-02': 2292,
#              '2019-03': 2350,
#              '2019-04': 2379,
#              '2019-05': 2167,
#              '2019-06': 1823,
#              '2019-07': 2275,
#              '2019-08': 2329,
#              '2019-09': 2191,
#              '2019-10': 2094,
#              '2019-11': 2200,
#              '2019-12': 2404,
#              '2020-01': 2419,
#              '2020-02': 2242,
#              '2020-03': 2152,
#              '2020-04': 2031,
#              '2020-05': 2147,
#              '2020-06': 2253,
#              '2020-07': 2442,
#              '2020-08': 2297,
#              '2020-09': 1350,
#              '2020-10': 1172,
#              '2020-11': 1509,
#              '2020-12': 1445,
#              '2021-01': 1292,
#              '2021-02': 1462,
#              '2021-03': 1542,
#              '2021-04': 1441,
#              '2021-05': 1458,
#              '2021-06': 1296,
#              '2021-07': 1268,
#              '2021-08': 1477,
#              '2021-09': 1420,
#              '2021-10': 1125,
#              '2021-11': 1087},
#  'NumActiveMon': 206,
#  'NumAuthors': 228,
#  'NumBlobs': 185522,
#  'NumCommits': 207994,
#  'NumCore': 13,
#  'NumFiles': 544,
#  'NumForks': 0,
#  'ProjectID': 'salsa.debian.org_security-tracker-team_security-tracker',
#  '_id': ObjectId('628e6482f7956706eaf876f6')}

# %% [markdown]
# ## Extracting projects' metadata

# %% [markdown]
# Let's do this for a few example projects, and create dataframe

# %%
from tqdm.notebook import trange, tqdm

# %%
projects_info=[]

for project in tqdm(projects[:10]):
    info = coll.find_one({'ProjectID': project},
                            {'_id': 0, 'CommunitySize': 1, 'NumCore': 1,
                             'EarliestCommitDate': 1, 'LatestCommitDate': 1,
                             'NumActiveMon': 1,
                             'NumAuthors': 1,
                             'NumBlobs': 1,
                             'NumCommits': 1,
                             'NumFiles': 1,
                             'NumForks': 1,
                             'NumStars': 1,
                             'ProjectID': 1,
                             'RootFork': 1,
                            })
    projects_info.append(info)
    
projects_info_df = pd.DataFrame.from_records(projects_info, index='ProjectID')
projects_info_df
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#                                                     NumAuthors  NumActiveMon  \
# ProjectID
# mirror-rpm_exim                                             35           111
# buildroot_buildroot                                       4347           259
# Exim_exim                                                  127           200
# pfsense_FreeBSD-ports                                     2520           329
# salsa.debian.org_security-tracker-team_security...         228           206
# git-portage_git-portage                                    457           182
# felenk_ports                                               321           294
# gentoo_gentoo                                             2600           257
# ulm_gentoo-x86-historical                                  668           182
# bitrig_bitrig-ports                                        108           236
#
#                                                     EarliestCommitDate  \
# ProjectID
# mirror-rpm_exim                                             1113883342
# buildroot_buildroot                                          958277795
# Exim_exim                                                   1097062611
# pfsense_FreeBSD-ports                                        769769985
# salsa.debian.org_security-tracker-team_security...          1098910404
# git-portage_git-portage                                      964744542
# felenk_ports                                                 833842030
# gentoo_gentoo                                                964744542
# ulm_gentoo-x86-historical                                    964744542
# bitrig_bitrig-ports                                          833842031
#
#                                                     NumBlobs  \
# ProjectID
# mirror-rpm_exim                                          396
# buildroot_buildroot                                   694969
# Exim_exim                                              49948
# pfsense_FreeBSD-ports                                2951925
# salsa.debian.org_security-tracker-team_security...    185522
# git-portage_git-portage                              3494204
# felenk_ports                                          644444
# gentoo_gentoo                                       18381095
# ulm_gentoo-x86-historical                            3406841
# bitrig_bitrig-ports                                   484272
#
#                                                     LatestCommitDate  NumCore  \
# ProjectID
# mirror-rpm_exim                                           1626906630        6
# buildroot_buildroot                                       1637721166      239
# Exim_exim                                                 1636918288        6
# pfsense_FreeBSD-ports                                     1637330126      210
# salsa.debian.org_security-tracker-team_security...        1637978885       13
# git-portage_git-portage                                   1439152874      107
# felenk_ports                                              1631646578       32
# gentoo_gentoo                                             1635933891      156
# ulm_gentoo-x86-historical                                 1439152874      125
# bitrig_bitrig-ports                                       1482248561        1
#
#                                                     NumFiles  CommunitySize  \
# ProjectID
# mirror-rpm_exim                                          159              1
# buildroot_buildroot                                   604548           4897
# Exim_exim                                               7455            130
# pfsense_FreeBSD-ports                                1277004           1184
# salsa.debian.org_security-tracker-team_security...       544             27
# git-portage_git-portage                               566640              5
# felenk_ports                                          134361             61
# gentoo_gentoo                                        1142501           1268
# ulm_gentoo-x86-historical                             566553              1
# bitrig_bitrig-ports                                   106501             26
#
#                                                     NumCommits  NumForks  \
# ProjectID
# mirror-rpm_exim                                            224         0
# buildroot_buildroot                                     375883      4390
# Exim_exim                                                 8456       132
# pfsense_FreeBSD-ports                                  4659656      1340
# salsa.debian.org_security-tracker-team_security...      207994         0
# git-portage_git-portage                                2212980         3
# felenk_ports                                            488853        78
# gentoo_gentoo                                          5303764      1651
# ulm_gentoo-x86-historical                              1688485         0
# bitrig_bitrig-ports                                     170590        30
#
#                                                                    RootFork  \
# ProjectID
# mirror-rpm_exim                                                         NaN
# buildroot_buildroot                                     buildroot_buildroot
# Exim_exim                                                         Exim_exim
# pfsense_FreeBSD-ports                                 freebsd_freebsd-ports
# salsa.debian.org_security-tracker-team_security...                      NaN
# git-portage_git-portage                             git-portage_git-portage
# felenk_ports                                                  openbsd_ports
# gentoo_gentoo                                                 gentoo_gentoo
# ulm_gentoo-x86-historical                                               NaN
# bitrig_bitrig-ports                                     bitrig_bitrig-ports
#
#                                                     NumStars
# ProjectID
# mirror-rpm_exim                                          NaN
# buildroot_buildroot                                  12124.0
# Exim_exim                                              542.0
# pfsense_FreeBSD-ports                                 1483.0
# salsa.debian.org_security-tracker-team_security...       NaN
# git-portage_git-portage                                  6.0
# felenk_ports                                           324.0
# gentoo_gentoo                                         1648.0
# ulm_gentoo-x86-historical                                NaN
# bitrig_bitrig-ports                                     28.0
